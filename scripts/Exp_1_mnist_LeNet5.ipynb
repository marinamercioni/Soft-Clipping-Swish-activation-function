# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
from __future__ import print_function
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.layers import AlphaDropout
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# %%
# Add the swish function to Keras
import tensorflow as tf
from tensorflow.keras.activations import softplus, tanh, sigmoid, softplus, elu, selu, relu, softsign, hard_sigmoid
from tensorflow.keras.layers import Activation
from tensorflow.keras.backend import sin
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras.layers import ThresholdedReLU


#learnable param
# beta=tf.Variable(0.1)
# def swish(x):
#     return x*tf.math.sigmoid(beta*x)
# get_custom_objects().update({'Swish':Activation(swish)})

from tensorflow.keras.activations import sigmoid, relu, tanh, softplus, selu, elu, softsign
def SoftClipping_Swish(x):
    return tf.maximum(0.0, swish(x))
get_custom_objects().update({'SC Swish':Activation(SoftClipping_Swish)})

def swish(x):
    return x*sigmoid(x)
get_custom_objects().update({'Swish':Activation(swish)})

act_func = ['sigmoid', 'tanh', 'relu', 'Swish', 'SC Swish']

# %% [markdown]
# TF Implementing LeNet-5 in TensorFlow 2.0

# %%
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.layers import Dense, Flatten, Conv2D, AveragePooling2D

from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

#from __future__ import absolute_import, division, print_function, unicode_literals

# %%
# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_train[0].shape, 'image shape')
# Out:
# x_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples
# (28, 28) image shape

# %%
# Add a new axis
x_train = x_train[:, :, :, np.newaxis]
x_test = x_test[:, :, :, np.newaxis]

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_train[0].shape, 'image shape')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# (28, 28, 1) image shape

# %%
# Convert class vectors to binary class matrices.
data_augmentation = False
epochs = 20
batch_size = 128
num_classes = 10

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
# Data normalization
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
# LeNet-5 model
for activation in act_func:
    class LeNet(Sequential):
        def __init__(self, input_shape, nb_classes):
            super().__init__()

            self.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation=activation, input_shape=input_shape, padding="same"))
            self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
            self.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation=activation, padding='valid'))
            self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
            self.add(Flatten())
            self.add(Dense(120, activation=activation))
            self.add(Dense(84, activation=activation))
            self.add(Dense(nb_classes, activation='softmax'))

            self.compile(optimizer='adam',
                        loss=categorical_crossentropy,
                        metrics=['accuracy'])

# %%
model = LeNet(x_train[0].shape, num_classes)

# %%
model.summary()
# Out:
# Model: "le_net_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_4 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_5 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten_2 (Flatten)         (None, 400)               0
#
#  dense_6 (Dense)             (None, 120)               48120
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Place the logs in a timestamped subdirectory
# This allows to easy select different training runs
# In order not to overwrite some data, it is useful to have a name with a timestamp
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# Specify the callback object
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# tf.keras.callback.TensorBoard ensures that logs are created and stored
# We need to pass callback object to the fit method
# The way to do this is by passing the list of callback objects, which is in our case just one

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-5
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

version=5
depth=8
# Model name, depth and version
model_type = 'LeNet%dv%d' % (depth, version)

# Prepare callbacks for model saving and for learning rate adjustment.
earlyStopping = EarlyStopping(monitor='val_accuracy', 
                              min_delta=0, 
                              patience=5, 
                              verbose=0, mode='auto', 
                              baseline=None, 
                              restore_best_weights=True)
#path to save the checkpoints
filepath="saved_models/Cifar10-LeNet5-{epoch:02d}-{val_accuracy:.2f}.hdf5"

#save checkpoint
checkpoint = ModelCheckpoint(filepath,monitor = "val_accuracy",verbose = 1, save_weights_only= True, save_best_only =True, mode = 'max')
lr_scheduler = LearningRateScheduler(lr_schedule)

# lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                                cooldown=0,
#                                patience=5,
#                                min_lr=0.5e-6)
tb=TensorBoard(log_dir='./logs', 
               histogram_freq=0, 
               write_graph=True, 
               write_grads=False, 
               write_images=True, 
               embeddings_freq=0, 
               embeddings_layer_names=None,
               embeddings_metadata=None, embeddings_data=None, update_freq='epoch')


callbacks = [earlyStopping, lr_scheduler, tb]

# %%
result = []
final_acc = []
final_loss = []
name=[]
for activation in act_func:
    print('\nTraining with -->{0}<-- activation function\n'.format(activation))
#     model = model(activation=activation,
#                               input_shape=input_shape,
#                               depth=depth)
    # Run training, with or without data augmentation.
    if not data_augmentation:
        print('Not using data augmentation.')
        history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True,
                  callbacks=callbacks)
        result.append(history)
        final_acc.append(history.history['val_accuracy'][-1])
        final_loss.append(history.history['val_loss'][-1])
        name.append(activation)
        
        print('{} \n val loss: {}, val acc: {}\n'.format(activation,history.history['val_loss'][-1], history.history['val_accuracy'][-1]))
    else:
        print('Using real-time data augmentation.')
        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            # set input mean to 0 over the dataset
            featurewise_center=False,
            # set each sample mean to 0
            samplewise_center=False,
            # divide inputs by std of dataset
            featurewise_std_normalization=False,
            # divide each input by its std
            samplewise_std_normalization=False,
            # apply ZCA whitening
            zca_whitening=False,
            # epsilon for ZCA whitening
            zca_epsilon=1e-06,
            # randomly rotate images in the range (deg 0 to 180)
            rotation_range=0,
            # randomly shift images horizontally
            width_shift_range=0.1,
            # randomly shift images vertically
            height_shift_range=0.1,
            # set range for random shear
            shear_range=0.,
            # set range for random zoom
            zoom_range=0.,
            # set range for random channel shifts
            channel_shift_range=0.,
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            # value used for fill_mode = "constant"
            cval=0.,
            # randomly flip images
            horizontal_flip=True,
            # randomly flip images
            vertical_flip=False,
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

        # Compute quantities required for featurewise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        history = datagen.fit(x_train)

        # Fit the model on the batches generated by datagen.flow().
        history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                            validation_data=(x_test, y_test),
                            epochs=epochs, verbose=1, workers=4,
                            callbacks=callbacks)
        result = result.append(history)
        final_acc = final_acc.append(history.history['val_accuracy'][-1])
        final_loss = final_loss.append(history.history['val_loss'][-1])
        name = name.append(activation)
        
        print('{} \n val loss: {}, val acc: {}\n'.format(activation,history.history['val_loss'][-1], history.history['val_accuracy'][-1]))

print(result)
# Out:
# Training with -->sigmoid<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/20
# 469/469 [==============================] - 14s 5ms/step - loss: 2.3003 - accuracy: 0.2623 - val_loss: 2.2966 - val_accuracy: 0.3345 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 2.2867 - accuracy: 0.3916 - val_loss: 2.2689 - val_accuracy: 0.4613 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 2.2231 - accuracy: 0.4690 - val_loss: 2.1367 - val_accuracy: 0.5068 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 1.9164 - accuracy: 0.5404 - val_loss: 1.5701 - val_accuracy: 0.6618 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/20
# 469/469 [==============================] - 3s 5ms/step - loss: 1.2846 - accuracy: 0.7028 - val_loss: 1.0121 - val_accuracy: 0.7530 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.9228 - accuracy: 0.7591 - val_loss: 0.7888 - val_accuracy: 0.7853 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.7620 - accuracy: 0.7883 - val_loss: 0.6781 - val_accuracy: 0.8108 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.6751 - accuracy: 0.8070 - val_loss: 0.6144 - val_accuracy: 0.8240 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6204 - accuracy: 0.8199 - val_loss: 0.5716 - val_accuracy: 0.8358 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5825 - accuracy: 0.8298 - val_loss: 0.5411 - val_accuracy: 0.8427 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5538 - accuracy: 0.8382 - val_loss: 0.5189 - val_accuracy: 0.8495 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5319 - accuracy: 0.8447 - val_loss: 0.4993 - val_accuracy: 0.8554 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5130 - accuracy: 0.8498 - val_loss: 0.4824 - val_accuracy: 0.8602 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4968 - accuracy: 0.8544 - val_loss: 0.4675 - val_accuracy: 0.8655 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4828 - accuracy: 0.8593 - val_loss: 0.4558 - val_accuracy: 0.8689 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4705 - accuracy: 0.8630 - val_loss: 0.4453 - val_accuracy: 0.8728 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4595 - accuracy: 0.8667 - val_loss: 0.4341 - val_accuracy: 0.8763 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4492 - accuracy: 0.8698 - val_loss: 0.4257 - val_accuracy: 0.8784 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4399 - accuracy: 0.8721 - val_loss: 0.4162 - val_accuracy: 0.8810 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4313 - accuracy: 0.8737 - val_loss: 0.4087 - val_accuracy: 0.8837 - lr: 1.0000e-05
# sigmoid
#  val loss: 0.4087252914905548, val acc: 0.8837000131607056
#
#
# Training with -->tanh<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4230 - accuracy: 0.8770 - val_loss: 0.4010 - val_accuracy: 0.8848 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4160 - accuracy: 0.8795 - val_loss: 0.3954 - val_accuracy: 0.8859 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4089 - accuracy: 0.8811 - val_loss: 0.3888 - val_accuracy: 0.8884 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4026 - accuracy: 0.8828 - val_loss: 0.3811 - val_accuracy: 0.8900 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3962 - accuracy: 0.8849 - val_loss: 0.3766 - val_accuracy: 0.8904 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3905 - accuracy: 0.8870 - val_loss: 0.3705 - val_accuracy: 0.8917 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3850 - accuracy: 0.8887 - val_loss: 0.3646 - val_accuracy: 0.8955 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3800 - accuracy: 0.8895 - val_loss: 0.3615 - val_accuracy: 0.8952 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3750 - accuracy: 0.8916 - val_loss: 0.3541 - val_accuracy: 0.8960 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3702 - accuracy: 0.8921 - val_loss: 0.3501 - val_accuracy: 0.8990 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3655 - accuracy: 0.8939 - val_loss: 0.3457 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3611 - accuracy: 0.8953 - val_loss: 0.3414 - val_accuracy: 0.9006 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3565 - accuracy: 0.8969 - val_loss: 0.3374 - val_accuracy: 0.9023 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3521 - accuracy: 0.8981 - val_loss: 0.3325 - val_accuracy: 0.9032 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3479 - accuracy: 0.8990 - val_loss: 0.3282 - val_accuracy: 0.9052 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3438 - accuracy: 0.9000 - val_loss: 0.3263 - val_accuracy: 0.9071 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3398 - accuracy: 0.9012 - val_loss: 0.3199 - val_accuracy: 0.9084 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3360 - accuracy: 0.9021 - val_loss: 0.3170 - val_accuracy: 0.9105 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3320 - accuracy: 0.9036 - val_loss: 0.3140 - val_accuracy: 0.9095 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3282 - accuracy: 0.9046 - val_loss: 0.3118 - val_accuracy: 0.9104 - lr: 1.0000e-05
# tanh
#  val loss: 0.3117949068546295, val acc: 0.9103999733924866
#
#
# Training with -->relu<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3244 - accuracy: 0.9057 - val_loss: 0.3076 - val_accuracy: 0.9118 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3206 - accuracy: 0.9073 - val_loss: 0.3018 - val_accuracy: 0.9128 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3171 - accuracy: 0.9083 - val_loss: 0.2977 - val_accuracy: 0.9135 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3131 - accuracy: 0.9087 - val_loss: 0.2973 - val_accuracy: 0.9156 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3094 - accuracy: 0.9103 - val_loss: 0.2916 - val_accuracy: 0.9158 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3058 - accuracy: 0.9108 - val_loss: 0.2869 - val_accuracy: 0.9169 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3020 - accuracy: 0.9121 - val_loss: 0.2828 - val_accuracy: 0.9181 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2986 - accuracy: 0.9131 - val_loss: 0.2821 - val_accuracy: 0.9180 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2949 - accuracy: 0.9143 - val_loss: 0.2790 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2913 - accuracy: 0.9150 - val_loss: 0.2724 - val_accuracy: 0.9211 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2880 - accuracy: 0.9157 - val_loss: 0.2704 - val_accuracy: 0.9219 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2843 - accuracy: 0.9175 - val_loss: 0.2662 - val_accuracy: 0.9219 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2807 - accuracy: 0.9186 - val_loss: 0.2628 - val_accuracy: 0.9252 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2772 - accuracy: 0.9201 - val_loss: 0.2590 - val_accuracy: 0.9249 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2739 - accuracy: 0.9204 - val_loss: 0.2557 - val_accuracy: 0.9260 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2707 - accuracy: 0.9212 - val_loss: 0.2555 - val_accuracy: 0.9263 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2670 - accuracy: 0.9227 - val_loss: 0.2509 - val_accuracy: 0.9269 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2638 - accuracy: 0.9233 - val_loss: 0.2467 - val_accuracy: 0.9293 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2604 - accuracy: 0.9244 - val_loss: 0.2450 - val_accuracy: 0.9297 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2575 - accuracy: 0.9262 - val_loss: 0.2392 - val_accuracy: 0.9313 - lr: 1.0000e-05
# relu
#  val loss: 0.2391858696937561, val acc: 0.9312999844551086
#
#
# Training with -->Swish<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2541 - accuracy: 0.9266 - val_loss: 0.2369 - val_accuracy: 0.9314 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2507 - accuracy: 0.9276 - val_loss: 0.2329 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2476 - accuracy: 0.9287 - val_loss: 0.2302 - val_accuracy: 0.9337 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2445 - accuracy: 0.9300 - val_loss: 0.2283 - val_accuracy: 0.9327 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2414 - accuracy: 0.9305 - val_loss: 0.2240 - val_accuracy: 0.9344 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2384 - accuracy: 0.9317 - val_loss: 0.2210 - val_accuracy: 0.9360 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2354 - accuracy: 0.9322 - val_loss: 0.2192 - val_accuracy: 0.9362 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2324 - accuracy: 0.9329 - val_loss: 0.2156 - val_accuracy: 0.9389 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2297 - accuracy: 0.9338 - val_loss: 0.2118 - val_accuracy: 0.9397 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2269 - accuracy: 0.9352 - val_loss: 0.2095 - val_accuracy: 0.9404 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2239 - accuracy: 0.9359 - val_loss: 0.2065 - val_accuracy: 0.9405 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2211 - accuracy: 0.9362 - val_loss: 0.2031 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2186 - accuracy: 0.9371 - val_loss: 0.2018 - val_accuracy: 0.9431 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2160 - accuracy: 0.9381 - val_loss: 0.1997 - val_accuracy: 0.9440 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2132 - accuracy: 0.9387 - val_loss: 0.1956 - val_accuracy: 0.9449 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2107 - accuracy: 0.9395 - val_loss: 0.1958 - val_accuracy: 0.9439 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2085 - accuracy: 0.9399 - val_loss: 0.1920 - val_accuracy: 0.9459 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2060 - accuracy: 0.9403 - val_loss: 0.1901 - val_accuracy: 0.9471 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2037 - accuracy: 0.9413 - val_loss: 0.1882 - val_accuracy: 0.9467 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2014 - accuracy: 0.9416 - val_loss: 0.1844 - val_accuracy: 0.9485 - lr: 1.0000e-05
# Swish
#  val loss: 0.18438386917114258, val acc: 0.9484999775886536
#
#
# Training with -->SC Swish<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1992 - accuracy: 0.9425 - val_loss: 0.1824 - val_accuracy: 0.9488 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1970 - accuracy: 0.9434 - val_loss: 0.1808 - val_accuracy: 0.9491 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1946 - accuracy: 0.9439 - val_loss: 0.1772 - val_accuracy: 0.9506 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1928 - accuracy: 0.9444 - val_loss: 0.1769 - val_accuracy: 0.9497 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1907 - accuracy: 0.9451 - val_loss: 0.1739 - val_accuracy: 0.9508 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1885 - accuracy: 0.9461 - val_loss: 0.1713 - val_accuracy: 0.9518 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1865 - accuracy: 0.9462 - val_loss: 0.1703 - val_accuracy: 0.9525 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1846 - accuracy: 0.9467 - val_loss: 0.1678 - val_accuracy: 0.9520 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1830 - accuracy: 0.9474 - val_loss: 0.1663 - val_accuracy: 0.9525 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1809 - accuracy: 0.9479 - val_loss: 0.1640 - val_accuracy: 0.9530 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1791 - accuracy: 0.9485 - val_loss: 0.1628 - val_accuracy: 0.9534 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1774 - accuracy: 0.9489 - val_loss: 0.1604 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1755 - accuracy: 0.9497 - val_loss: 0.1588 - val_accuracy: 0.9558 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1739 - accuracy: 0.9505 - val_loss: 0.1588 - val_accuracy: 0.9546 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1722 - accuracy: 0.9504 - val_loss: 0.1578 - val_accuracy: 0.9553 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1703 - accuracy: 0.9511 - val_loss: 0.1550 - val_accuracy: 0.9562 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1689 - accuracy: 0.9514 - val_loss: 0.1535 - val_accuracy: 0.9565 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1672 - accuracy: 0.9521 - val_loss: 0.1510 - val_accuracy: 0.9577 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1657 - accuracy: 0.9527 - val_loss: 0.1505 - val_accuracy: 0.9574 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1644 - accuracy: 0.9526 - val_loss: 0.1483 - val_accuracy: 0.9569 - lr: 1.0000e-05
# SC Swish
#  val loss: 0.14829444885253906, val acc: 0.9569000005722046
#
# [<keras.callbacks.History object at 0x7ff0b02470d0>, <keras.callbacks.History object at 0x7ff04860fdd0>, <keras.callbacks.History object at 0x7ff0485c5890>, <keras.callbacks.History object at 0x7ff048592410>, <keras.callbacks.History object at 0x7ff0484d7950>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

new_act_arr = act_func[0:]
new_results = result[0:]

def plot_act_func_results(results, activation_functions = []):
    plt.figure(figsize=(10,10))
    plt.style.use('seaborn-poster')
    
    # Plot validation accuracy values
    for act_func in results:
        plt.plot(act_func.history['val_accuracy'])
        
    plt.title('Model accuracy')
    plt.ylabel('Test Accuracy')
    plt.xlabel('Epoch')
    plt.legend(activation_functions)
    plt.show()

    # Plot validation loss values
    plt.figure(figsize=(10,10))
    
    for act_func in results:
        plt.plot(act_func.history['val_loss'])
        
    plt.title('Model loss')
    plt.ylabel('Test Loss')
    plt.xlabel('Epoch')
    plt.legend(activation_functions)
    plt.show()

plot_act_func_results(new_results, new_act_arr)

# %%
# evaluate the model
scores = model.evaluate(x_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 95.69%
