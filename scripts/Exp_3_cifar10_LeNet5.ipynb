# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
from __future__ import print_function
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.layers import AlphaDropout
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam

# %%
# Add the swish function to Keras
import tensorflow as tf
from tensorflow.keras.activations import softplus, tanh, sigmoid, softplus, elu, selu, relu, softsign, hard_sigmoid
from tensorflow.keras.layers import Activation
from tensorflow.keras.backend import sin
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras.layers import ThresholdedReLU


#learnable param
# beta=tf.Variable(0.1)
# def swish(x):
#     return x*tf.math.sigmoid(beta*x)
# get_custom_objects().update({'Swish':Activation(swish)})

from tensorflow.keras.activations import sigmoid, relu, tanh, softplus, selu, elu, softsign
def SoftClipping_Swish(x):
    return tf.maximum(0.0, swish(x))
get_custom_objects().update({'SC Swish':Activation(SoftClipping_Swish)})

def swish(x):
    return x*sigmoid(x)
get_custom_objects().update({'Swish':Activation(swish)})

act_func = ['sigmoid', 'tanh', 'relu', 'Swish', 'SC Swish']

# %%
from tensorflow.keras.datasets import cifar10
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_train[0].shape, 'image shape')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# (32, 32, 3) image shape

# %%
# Training parameters
# batch_size = 32  # orig paper trained all networks with batch_size=128
batch_size = 128
epochs = 50
data_augmentation = False
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True


def preprocess_cifar10(x_train, y_train, x_test, y_test):
    # Input image dimensions.
    input_shape = x_train.shape[1:]

    # Normalize data.
    x_train = x_train.astype('float32') / 255
    x_test = x_test.astype('float32') / 255

    # If subtract pixel mean is enabled
    if subtract_pixel_mean:
        x_train_mean = np.mean(x_train, axis=0)
        x_train -= x_train_mean
        x_test -= x_train_mean

    print('x_train shape:', x_train.shape)
    print(x_train.shape[0], 'train samples')
    print(x_test.shape[0], 'test samples')
    print('y_train shape:', y_train.shape)

    # Convert class vectors to binary class matrices.
    y_train = tf.keras.utils.to_categorical(y_train, num_classes)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes)
    
    return x_train, y_train, x_test, y_test, input_shape
    
x_train, y_train, x_test, y_test, input_shape = preprocess_cifar10(x_train, y_train, x_test, y_test)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-5
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
for activation in act_func:
    # LeNet-5 model
    class LeNet(Sequential):
        def __init__(self, input_shape, nb_classes):
            super().__init__()

            self.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation=activation, input_shape=input_shape, padding="same"))
            self.add(BatchNormalization())
            self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
            self.add(BatchNormalization())
            self.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation=activation, padding='valid'))
            self.add(BatchNormalization())
            self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
            self.add(Flatten())
            self.add(Dense(120, activation=activation))
            self.add(Dropout(0.2))
            self.add(Dense(84, activation=activation))
            self.add(Dense(nb_classes, activation='softmax'))

            self.compile(optimizer='adam',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

# %%
model = LeNet(x_train[0].shape, num_classes)

# %%
model.summary()
# Out:
# Model: "le_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 6)         456
#
#  batch_normalization (BatchN  (None, 32, 32, 6)        24
#  ormalization)
#
#  average_pooling2d (AverageP  (None, 16, 16, 6)        0
#  ooling2D)
#
#  batch_normalization_1 (Batc  (None, 16, 16, 6)        24
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 16)        2416
#
#  batch_normalization_2 (Batc  (None, 12, 12, 16)       64
#  hNormalization)
#
#  average_pooling2d_1 (Averag  (None, 6, 6, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 120)               69240
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 83,238
# Trainable params: 83,182
# Non-trainable params: 56
# _________________________________________________________________

# %%
import datetime
# Place the logs in a timestamped subdirectory
# This allows to easy select different training runs
# In order not to overwrite some data, it is useful to have a name with a timestamp
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# Specify the callback object
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# tf.keras.callback.TensorBoard ensures that logs are created and stored
# We need to pass callback object to the fit method
# The way to do this is by passing the list of callback objects, which is in our case just one

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

version=5
depth=8
# Model name, depth and version
model_type = 'LeNet%dv%d' % (depth, version)

# Prepare callbacks for model saving and for learning rate adjustment.
earlyStopping = EarlyStopping(monitor='val_accuracy', 
                              min_delta=0, 
                              patience=5, 
                              verbose=0, mode='auto', 
                              baseline=None, 
                              restore_best_weights=True)
#path to save the checkpoints
filepath="saved_models/Cifar10-LeNet5-{epoch:02d}-{val_accuracy:.2f}.hdf5"

#save checkpoint
checkpoint = ModelCheckpoint(filepath,monitor = "val_accuracy",verbose = 1, save_weights_only= True, save_best_only =True, mode = 'max')
lr_scheduler = LearningRateScheduler(lr_schedule)

# lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                                cooldown=0,
#                                patience=5,
#                                min_lr=0.5e-6)
tb=TensorBoard(log_dir='./logs', 
               histogram_freq=0, 
               write_graph=True, 
               write_grads=False, 
               write_images=True, 
               embeddings_freq=0, 
               embeddings_layer_names=None,
               embeddings_metadata=None, embeddings_data=None, update_freq='epoch')


callbacks = [earlyStopping, lr_scheduler, tb]

# %%
result = []
final_acc = []
final_loss = []
name=[]
for activation in act_func:
    print('\nTraining with -->{0}<-- activation function\n'.format(activation))
#     model = model(activation=activation,
#                               input_shape=input_shape,
#                               depth=depth)
    # Run training, with or without data augmentation.
    if not data_augmentation:
        print('Not using data augmentation.')
        history = model.fit(x_train, y_train,
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_data=(x_test, y_test),
                  shuffle=True,
                  callbacks=callbacks)
        result.append(history)
        final_acc.append(history.history['val_accuracy'][-1])
        final_loss.append(history.history['val_loss'][-1])
        name.append(activation)
        
        print('{} \n val loss: {}, val acc: {}\n'.format(activation,history.history['val_loss'][-1], history.history['val_accuracy'][-1]))
    else:
        print('Using real-time data augmentation.')
        # This will do preprocessing and realtime data augmentation:
        datagen = ImageDataGenerator(
            # set input mean to 0 over the dataset
            featurewise_center=False,
            # set each sample mean to 0
            samplewise_center=False,
            # divide inputs by std of dataset
            featurewise_std_normalization=False,
            # divide each input by its std
            samplewise_std_normalization=False,
            # apply ZCA whitening
            zca_whitening=False,
            # epsilon for ZCA whitening
            zca_epsilon=1e-06,
            # randomly rotate images in the range (deg 0 to 180)
            rotation_range=0,
            # randomly shift images horizontally
            width_shift_range=0.1,
            # randomly shift images vertically
            height_shift_range=0.1,
            # set range for random shear
            shear_range=0.,
            # set range for random zoom
            zoom_range=0.,
            # set range for random channel shifts
            channel_shift_range=0.,
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            # value used for fill_mode = "constant"
            cval=0.,
            # randomly flip images
            horizontal_flip=True,
            # randomly flip images
            vertical_flip=False,
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format=None,
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.0)

        # Compute quantities required for featurewise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
        history = datagen.fit(x_train)

        # Fit the model on the batches generated by datagen.flow().
        history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                            validation_data=(x_test, y_test),
                            epochs=epochs, verbose=1, workers=4,
                            callbacks=callbacks)
        result = result.append(history)
        final_acc = final_acc.append(history.history['val_accuracy'][-1])
        final_loss = final_loss.append(history.history['val_loss'][-1])
        name = name.append(activation)
        
        print('{} \n val loss: {}, val acc: {}\n'.format(activation,history.history['val_loss'][-1], history.history['val_accuracy'][-1]))

print(result)

# i=0


# a=0
# while(i<len(act_func)):
#     dict={name[i]: {final_acc[i], final_loss[i]}}
    
#     print(dict)
#     if i>0 and final_acc[i]>final_acc[i-1]:
#         a=final_acc[i]
#         nume=name[i]
#     i+=1
# print('Best acc made by function {} with acc of {}'.format(nume,a))
# Out:
# Training with -->sigmoid<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/50
# 391/391 [==============================] - 10s 12ms/step - loss: 2.3597 - accuracy: 0.1222 - val_loss: 2.2769 - val_accuracy: 0.1415 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2255 - accuracy: 0.1778 - val_loss: 2.1471 - val_accuracy: 0.2243 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.1334 - accuracy: 0.2257 - val_loss: 2.0536 - val_accuracy: 0.2648 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.0526 - accuracy: 0.2596 - val_loss: 1.9728 - val_accuracy: 0.2923 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.9802 - accuracy: 0.2874 - val_loss: 1.9044 - val_accuracy: 0.3136 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.9220 - accuracy: 0.3058 - val_loss: 1.8499 - val_accuracy: 0.3335 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.8778 - accuracy: 0.3209 - val_loss: 1.8079 - val_accuracy: 0.3486 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8375 - accuracy: 0.3336 - val_loss: 1.7742 - val_accuracy: 0.3580 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.8097 - accuracy: 0.3428 - val_loss: 1.7462 - val_accuracy: 0.3690 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.7839 - accuracy: 0.3513 - val_loss: 1.7218 - val_accuracy: 0.3777 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.7594 - accuracy: 0.3598 - val_loss: 1.6994 - val_accuracy: 0.3848 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.7375 - accuracy: 0.3701 - val_loss: 1.6787 - val_accuracy: 0.3944 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.7208 - accuracy: 0.3766 - val_loss: 1.6594 - val_accuracy: 0.4026 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6995 - accuracy: 0.3813 - val_loss: 1.6413 - val_accuracy: 0.4087 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6791 - accuracy: 0.3917 - val_loss: 1.6239 - val_accuracy: 0.4137 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6627 - accuracy: 0.3977 - val_loss: 1.6075 - val_accuracy: 0.4199 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6512 - accuracy: 0.4021 - val_loss: 1.5917 - val_accuracy: 0.4250 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6355 - accuracy: 0.4045 - val_loss: 1.5776 - val_accuracy: 0.4303 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.6207 - accuracy: 0.4130 - val_loss: 1.5637 - val_accuracy: 0.4361 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.6056 - accuracy: 0.4176 - val_loss: 1.5517 - val_accuracy: 0.4410 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5927 - accuracy: 0.4215 - val_loss: 1.5389 - val_accuracy: 0.4447 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5764 - accuracy: 0.4297 - val_loss: 1.5276 - val_accuracy: 0.4486 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5687 - accuracy: 0.4322 - val_loss: 1.5167 - val_accuracy: 0.4515 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 24/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5577 - accuracy: 0.4362 - val_loss: 1.5068 - val_accuracy: 0.4550 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 25/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5453 - accuracy: 0.4406 - val_loss: 1.4963 - val_accuracy: 0.4581 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 26/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5337 - accuracy: 0.4460 - val_loss: 1.4871 - val_accuracy: 0.4621 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 27/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5267 - accuracy: 0.4465 - val_loss: 1.4783 - val_accuracy: 0.4661 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5154 - accuracy: 0.4528 - val_loss: 1.4696 - val_accuracy: 0.4676 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 29/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.5081 - accuracy: 0.4551 - val_loss: 1.4614 - val_accuracy: 0.4709 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 30/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4958 - accuracy: 0.4587 - val_loss: 1.4534 - val_accuracy: 0.4749 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4912 - accuracy: 0.4608 - val_loss: 1.4459 - val_accuracy: 0.4778 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 32/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4816 - accuracy: 0.4663 - val_loss: 1.4388 - val_accuracy: 0.4809 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 33/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4748 - accuracy: 0.4669 - val_loss: 1.4319 - val_accuracy: 0.4844 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 34/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4673 - accuracy: 0.4705 - val_loss: 1.4246 - val_accuracy: 0.4855 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 35/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4596 - accuracy: 0.4737 - val_loss: 1.4187 - val_accuracy: 0.4880 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 36/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4545 - accuracy: 0.4765 - val_loss: 1.4125 - val_accuracy: 0.4899 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 37/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4451 - accuracy: 0.4779 - val_loss: 1.4062 - val_accuracy: 0.4923 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 38/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.4367 - accuracy: 0.4843 - val_loss: 1.4008 - val_accuracy: 0.4944 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 39/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.4322 - accuracy: 0.4834 - val_loss: 1.3954 - val_accuracy: 0.4960 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 40/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4274 - accuracy: 0.4859 - val_loss: 1.3900 - val_accuracy: 0.4984 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 41/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4227 - accuracy: 0.4863 - val_loss: 1.3849 - val_accuracy: 0.5018 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 42/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4132 - accuracy: 0.4904 - val_loss: 1.3794 - val_accuracy: 0.5019 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 43/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4079 - accuracy: 0.4924 - val_loss: 1.3745 - val_accuracy: 0.5054 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 44/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4043 - accuracy: 0.4940 - val_loss: 1.3699 - val_accuracy: 0.5065 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 45/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3993 - accuracy: 0.4973 - val_loss: 1.3649 - val_accuracy: 0.5082 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 46/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3911 - accuracy: 0.5020 - val_loss: 1.3606 - val_accuracy: 0.5105 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 47/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3892 - accuracy: 0.4999 - val_loss: 1.3564 - val_accuracy: 0.5120 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 48/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3867 - accuracy: 0.4999 - val_loss: 1.3519 - val_accuracy: 0.5145 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 49/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3761 - accuracy: 0.5049 - val_loss: 1.3477 - val_accuracy: 0.5175 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 50/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3745 - accuracy: 0.5068 - val_loss: 1.3435 - val_accuracy: 0.5185 - lr: 1.0000e-05
# sigmoid
#  val loss: 1.343517780303955, val acc: 0.5184999704360962
#
#
# Training with -->tanh<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3667 - accuracy: 0.5101 - val_loss: 1.3396 - val_accuracy: 0.5199 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3605 - accuracy: 0.5121 - val_loss: 1.3353 - val_accuracy: 0.5219 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3596 - accuracy: 0.5116 - val_loss: 1.3317 - val_accuracy: 0.5232 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3537 - accuracy: 0.5134 - val_loss: 1.3281 - val_accuracy: 0.5250 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3514 - accuracy: 0.5159 - val_loss: 1.3244 - val_accuracy: 0.5263 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3452 - accuracy: 0.5153 - val_loss: 1.3205 - val_accuracy: 0.5290 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3431 - accuracy: 0.5172 - val_loss: 1.3173 - val_accuracy: 0.5287 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3364 - accuracy: 0.5182 - val_loss: 1.3134 - val_accuracy: 0.5301 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3367 - accuracy: 0.5224 - val_loss: 1.3097 - val_accuracy: 0.5314 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3293 - accuracy: 0.5228 - val_loss: 1.3063 - val_accuracy: 0.5334 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3267 - accuracy: 0.5219 - val_loss: 1.3034 - val_accuracy: 0.5347 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3251 - accuracy: 0.5237 - val_loss: 1.3001 - val_accuracy: 0.5368 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3144 - accuracy: 0.5273 - val_loss: 1.2966 - val_accuracy: 0.5372 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3132 - accuracy: 0.5295 - val_loss: 1.2936 - val_accuracy: 0.5383 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3106 - accuracy: 0.5295 - val_loss: 1.2905 - val_accuracy: 0.5400 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3066 - accuracy: 0.5300 - val_loss: 1.2874 - val_accuracy: 0.5413 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.3032 - accuracy: 0.5340 - val_loss: 1.2845 - val_accuracy: 0.5413 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2956 - accuracy: 0.5367 - val_loss: 1.2813 - val_accuracy: 0.5431 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2956 - accuracy: 0.5336 - val_loss: 1.2784 - val_accuracy: 0.5442 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2931 - accuracy: 0.5360 - val_loss: 1.2763 - val_accuracy: 0.5447 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2894 - accuracy: 0.5375 - val_loss: 1.2727 - val_accuracy: 0.5475 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2874 - accuracy: 0.5395 - val_loss: 1.2701 - val_accuracy: 0.5472 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2810 - accuracy: 0.5395 - val_loss: 1.2671 - val_accuracy: 0.5491 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 24/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2772 - accuracy: 0.5420 - val_loss: 1.2646 - val_accuracy: 0.5500 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 25/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2776 - accuracy: 0.5408 - val_loss: 1.2623 - val_accuracy: 0.5512 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 26/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2696 - accuracy: 0.5452 - val_loss: 1.2594 - val_accuracy: 0.5515 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 27/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2686 - accuracy: 0.5452 - val_loss: 1.2566 - val_accuracy: 0.5521 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2638 - accuracy: 0.5479 - val_loss: 1.2556 - val_accuracy: 0.5519 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 29/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2662 - accuracy: 0.5457 - val_loss: 1.2520 - val_accuracy: 0.5548 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 30/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2604 - accuracy: 0.5486 - val_loss: 1.2498 - val_accuracy: 0.5543 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 31/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2589 - accuracy: 0.5490 - val_loss: 1.2475 - val_accuracy: 0.5554 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 32/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2567 - accuracy: 0.5515 - val_loss: 1.2455 - val_accuracy: 0.5572 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 33/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2499 - accuracy: 0.5524 - val_loss: 1.2429 - val_accuracy: 0.5574 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 34/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2493 - accuracy: 0.5522 - val_loss: 1.2409 - val_accuracy: 0.5565 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 35/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2469 - accuracy: 0.5560 - val_loss: 1.2390 - val_accuracy: 0.5582 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 36/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2426 - accuracy: 0.5552 - val_loss: 1.2363 - val_accuracy: 0.5596 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 37/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2397 - accuracy: 0.5568 - val_loss: 1.2336 - val_accuracy: 0.5609 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 38/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2362 - accuracy: 0.5588 - val_loss: 1.2324 - val_accuracy: 0.5611 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 39/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2337 - accuracy: 0.5614 - val_loss: 1.2293 - val_accuracy: 0.5627 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 40/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2302 - accuracy: 0.5585 - val_loss: 1.2276 - val_accuracy: 0.5624 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 41/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2287 - accuracy: 0.5611 - val_loss: 1.2249 - val_accuracy: 0.5631 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 42/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2280 - accuracy: 0.5597 - val_loss: 1.2231 - val_accuracy: 0.5643 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 43/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2221 - accuracy: 0.5618 - val_loss: 1.2211 - val_accuracy: 0.5646 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 44/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2185 - accuracy: 0.5633 - val_loss: 1.2187 - val_accuracy: 0.5656 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 45/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2146 - accuracy: 0.5665 - val_loss: 1.2165 - val_accuracy: 0.5673 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 46/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2159 - accuracy: 0.5664 - val_loss: 1.2146 - val_accuracy: 0.5674 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 47/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2121 - accuracy: 0.5669 - val_loss: 1.2133 - val_accuracy: 0.5686 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 48/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2086 - accuracy: 0.5670 - val_loss: 1.2108 - val_accuracy: 0.5676 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 49/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.2076 - accuracy: 0.5692 - val_loss: 1.2102 - val_accuracy: 0.5678 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 50/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.2035 - accuracy: 0.5703 - val_loss: 1.2073 - val_accuracy: 0.5704 - lr: 1.0000e-05
# tanh
#  val loss: 1.207341194152832, val acc: 0.5703999996185303
#
#
# Training with -->relu<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2027 - accuracy: 0.5689 - val_loss: 1.2050 - val_accuracy: 0.5706 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1996 - accuracy: 0.5700 - val_loss: 1.2038 - val_accuracy: 0.5711 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1977 - accuracy: 0.5712 - val_loss: 1.2030 - val_accuracy: 0.5721 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1976 - accuracy: 0.5720 - val_loss: 1.1997 - val_accuracy: 0.5730 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1924 - accuracy: 0.5753 - val_loss: 1.1978 - val_accuracy: 0.5731 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1895 - accuracy: 0.5758 - val_loss: 1.1967 - val_accuracy: 0.5748 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1875 - accuracy: 0.5743 - val_loss: 1.1949 - val_accuracy: 0.5750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1846 - accuracy: 0.5777 - val_loss: 1.1929 - val_accuracy: 0.5760 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1806 - accuracy: 0.5778 - val_loss: 1.1918 - val_accuracy: 0.5774 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1763 - accuracy: 0.5803 - val_loss: 1.1893 - val_accuracy: 0.5771 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1761 - accuracy: 0.5783 - val_loss: 1.1874 - val_accuracy: 0.5767 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1736 - accuracy: 0.5815 - val_loss: 1.1860 - val_accuracy: 0.5775 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1733 - accuracy: 0.5795 - val_loss: 1.1847 - val_accuracy: 0.5801 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1724 - accuracy: 0.5823 - val_loss: 1.1825 - val_accuracy: 0.5805 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1696 - accuracy: 0.5831 - val_loss: 1.1813 - val_accuracy: 0.5803 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1667 - accuracy: 0.5834 - val_loss: 1.1794 - val_accuracy: 0.5828 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1678 - accuracy: 0.5848 - val_loss: 1.1789 - val_accuracy: 0.5818 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1598 - accuracy: 0.5854 - val_loss: 1.1761 - val_accuracy: 0.5847 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1591 - accuracy: 0.5878 - val_loss: 1.1752 - val_accuracy: 0.5849 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1603 - accuracy: 0.5884 - val_loss: 1.1739 - val_accuracy: 0.5845 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1547 - accuracy: 0.5882 - val_loss: 1.1723 - val_accuracy: 0.5838 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1517 - accuracy: 0.5881 - val_loss: 1.1706 - val_accuracy: 0.5859 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1518 - accuracy: 0.5919 - val_loss: 1.1685 - val_accuracy: 0.5856 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1522 - accuracy: 0.5887 - val_loss: 1.1679 - val_accuracy: 0.5855 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 25/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1509 - accuracy: 0.5904 - val_loss: 1.1663 - val_accuracy: 0.5858 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 26/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1443 - accuracy: 0.5913 - val_loss: 1.1651 - val_accuracy: 0.5863 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 27/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1421 - accuracy: 0.5933 - val_loss: 1.1629 - val_accuracy: 0.5877 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 28/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1380 - accuracy: 0.5940 - val_loss: 1.1621 - val_accuracy: 0.5875 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 29/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1403 - accuracy: 0.5920 - val_loss: 1.1622 - val_accuracy: 0.5900 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1387 - accuracy: 0.5941 - val_loss: 1.1590 - val_accuracy: 0.5889 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 31/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1370 - accuracy: 0.5939 - val_loss: 1.1579 - val_accuracy: 0.5888 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 32/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1358 - accuracy: 0.5965 - val_loss: 1.1570 - val_accuracy: 0.5887 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1349 - accuracy: 0.5963 - val_loss: 1.1555 - val_accuracy: 0.5898 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 34/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1318 - accuracy: 0.5975 - val_loss: 1.1532 - val_accuracy: 0.5907 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1287 - accuracy: 0.5985 - val_loss: 1.1533 - val_accuracy: 0.5903 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1240 - accuracy: 0.6012 - val_loss: 1.1512 - val_accuracy: 0.5902 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1214 - accuracy: 0.6020 - val_loss: 1.1499 - val_accuracy: 0.5916 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1248 - accuracy: 0.5977 - val_loss: 1.1497 - val_accuracy: 0.5926 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 39/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1212 - accuracy: 0.6002 - val_loss: 1.1487 - val_accuracy: 0.5928 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1171 - accuracy: 0.6018 - val_loss: 1.1468 - val_accuracy: 0.5937 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1180 - accuracy: 0.6013 - val_loss: 1.1452 - val_accuracy: 0.5947 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1147 - accuracy: 0.6037 - val_loss: 1.1437 - val_accuracy: 0.5949 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1106 - accuracy: 0.6050 - val_loss: 1.1429 - val_accuracy: 0.5947 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 44/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1104 - accuracy: 0.6041 - val_loss: 1.1420 - val_accuracy: 0.5959 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 45/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1104 - accuracy: 0.6063 - val_loss: 1.1410 - val_accuracy: 0.5972 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 46/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1087 - accuracy: 0.6055 - val_loss: 1.1401 - val_accuracy: 0.5974 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 47/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1052 - accuracy: 0.6075 - val_loss: 1.1376 - val_accuracy: 0.5969 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 48/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1028 - accuracy: 0.6070 - val_loss: 1.1370 - val_accuracy: 0.5977 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 49/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.1034 - accuracy: 0.6053 - val_loss: 1.1353 - val_accuracy: 0.5997 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 50/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.1024 - accuracy: 0.6092 - val_loss: 1.1346 - val_accuracy: 0.5991 - lr: 1.0000e-05
# relu
#  val loss: 1.1346442699432373, val acc: 0.5990999937057495
#
#
# Training with -->Swish<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0988 - accuracy: 0.6111 - val_loss: 1.1332 - val_accuracy: 0.5987 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0965 - accuracy: 0.6093 - val_loss: 1.1326 - val_accuracy: 0.5988 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0958 - accuracy: 0.6109 - val_loss: 1.1320 - val_accuracy: 0.5996 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0930 - accuracy: 0.6109 - val_loss: 1.1304 - val_accuracy: 0.6011 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0957 - accuracy: 0.6097 - val_loss: 1.1294 - val_accuracy: 0.6017 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0910 - accuracy: 0.6126 - val_loss: 1.1276 - val_accuracy: 0.6004 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0853 - accuracy: 0.6134 - val_loss: 1.1274 - val_accuracy: 0.6022 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0857 - accuracy: 0.6133 - val_loss: 1.1263 - val_accuracy: 0.6017 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0835 - accuracy: 0.6152 - val_loss: 1.1255 - val_accuracy: 0.6027 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0838 - accuracy: 0.6149 - val_loss: 1.1240 - val_accuracy: 0.6031 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0836 - accuracy: 0.6158 - val_loss: 1.1236 - val_accuracy: 0.6027 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0819 - accuracy: 0.6155 - val_loss: 1.1217 - val_accuracy: 0.6033 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0781 - accuracy: 0.6159 - val_loss: 1.1210 - val_accuracy: 0.6037 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0778 - accuracy: 0.6167 - val_loss: 1.1195 - val_accuracy: 0.6037 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0711 - accuracy: 0.6186 - val_loss: 1.1192 - val_accuracy: 0.6046 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0757 - accuracy: 0.6178 - val_loss: 1.1179 - val_accuracy: 0.6045 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0718 - accuracy: 0.6184 - val_loss: 1.1169 - val_accuracy: 0.6054 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0728 - accuracy: 0.6186 - val_loss: 1.1160 - val_accuracy: 0.6055 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0685 - accuracy: 0.6203 - val_loss: 1.1158 - val_accuracy: 0.6071 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/50
# 391/391 [==============================] - 2s 6ms/step - loss: 1.0677 - accuracy: 0.6227 - val_loss: 1.1148 - val_accuracy: 0.6061 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0652 - accuracy: 0.6221 - val_loss: 1.1128 - val_accuracy: 0.6062 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0626 - accuracy: 0.6238 - val_loss: 1.1116 - val_accuracy: 0.6067 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0611 - accuracy: 0.6242 - val_loss: 1.1110 - val_accuracy: 0.6064 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0624 - accuracy: 0.6214 - val_loss: 1.1104 - val_accuracy: 0.6073 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 25/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0599 - accuracy: 0.6255 - val_loss: 1.1087 - val_accuracy: 0.6081 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 26/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0586 - accuracy: 0.6227 - val_loss: 1.1086 - val_accuracy: 0.6080 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0553 - accuracy: 0.6241 - val_loss: 1.1077 - val_accuracy: 0.6092 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 28/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0530 - accuracy: 0.6258 - val_loss: 1.1061 - val_accuracy: 0.6095 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 29/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0539 - accuracy: 0.6250 - val_loss: 1.1058 - val_accuracy: 0.6090 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0505 - accuracy: 0.6270 - val_loss: 1.1055 - val_accuracy: 0.6105 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 31/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0519 - accuracy: 0.6245 - val_loss: 1.1044 - val_accuracy: 0.6112 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 32/50
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0521 - accuracy: 0.6264 - val_loss: 1.1041 - val_accuracy: 0.6111 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 33/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0472 - accuracy: 0.6287 - val_loss: 1.1021 - val_accuracy: 0.6116 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 34/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0451 - accuracy: 0.6294 - val_loss: 1.1016 - val_accuracy: 0.6114 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 35/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0467 - accuracy: 0.6279 - val_loss: 1.1011 - val_accuracy: 0.6113 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 36/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0451 - accuracy: 0.6297 - val_loss: 1.1002 - val_accuracy: 0.6121 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 37/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0406 - accuracy: 0.6326 - val_loss: 1.0997 - val_accuracy: 0.6140 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 38/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0387 - accuracy: 0.6322 - val_loss: 1.0991 - val_accuracy: 0.6124 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0416 - accuracy: 0.6296 - val_loss: 1.0975 - val_accuracy: 0.6126 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0406 - accuracy: 0.6322 - val_loss: 1.0970 - val_accuracy: 0.6124 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0356 - accuracy: 0.6319 - val_loss: 1.0976 - val_accuracy: 0.6118 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 42/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0352 - accuracy: 0.6326 - val_loss: 1.0957 - val_accuracy: 0.6142 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0330 - accuracy: 0.6343 - val_loss: 1.0939 - val_accuracy: 0.6144 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 44/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0302 - accuracy: 0.6352 - val_loss: 1.0944 - val_accuracy: 0.6139 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 45/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0334 - accuracy: 0.6363 - val_loss: 1.0929 - val_accuracy: 0.6150 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0271 - accuracy: 0.6338 - val_loss: 1.0925 - val_accuracy: 0.6152 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0272 - accuracy: 0.6346 - val_loss: 1.0916 - val_accuracy: 0.6131 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0245 - accuracy: 0.6386 - val_loss: 1.0919 - val_accuracy: 0.6165 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0233 - accuracy: 0.6373 - val_loss: 1.0898 - val_accuracy: 0.6151 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 50/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0238 - accuracy: 0.6362 - val_loss: 1.0896 - val_accuracy: 0.6146 - lr: 1.0000e-05
# Swish
#  val loss: 1.089550256729126, val acc: 0.6146000027656555
#
#
# Training with -->SC Swish<-- activation function
#
# Not using data augmentation.
# Learning rate:  1e-05
# Epoch 1/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0205 - accuracy: 0.6381 - val_loss: 1.0895 - val_accuracy: 0.6144 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 2/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0194 - accuracy: 0.6383 - val_loss: 1.0879 - val_accuracy: 0.6164 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0181 - accuracy: 0.6386 - val_loss: 1.0872 - val_accuracy: 0.6161 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 4/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0182 - accuracy: 0.6402 - val_loss: 1.0864 - val_accuracy: 0.6172 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0154 - accuracy: 0.6408 - val_loss: 1.0858 - val_accuracy: 0.6178 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 6/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0155 - accuracy: 0.6401 - val_loss: 1.0854 - val_accuracy: 0.6172 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0159 - accuracy: 0.6409 - val_loss: 1.0851 - val_accuracy: 0.6178 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0122 - accuracy: 0.6415 - val_loss: 1.0840 - val_accuracy: 0.6181 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0121 - accuracy: 0.6418 - val_loss: 1.0834 - val_accuracy: 0.6177 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 10/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0098 - accuracy: 0.6386 - val_loss: 1.0832 - val_accuracy: 0.6177 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0074 - accuracy: 0.6420 - val_loss: 1.0822 - val_accuracy: 0.6195 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0079 - accuracy: 0.6413 - val_loss: 1.0813 - val_accuracy: 0.6189 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 13/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0080 - accuracy: 0.6438 - val_loss: 1.0806 - val_accuracy: 0.6185 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 14/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0024 - accuracy: 0.6445 - val_loss: 1.0795 - val_accuracy: 0.6181 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 15/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0041 - accuracy: 0.6431 - val_loss: 1.0793 - val_accuracy: 0.6192 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0019 - accuracy: 0.6460 - val_loss: 1.0785 - val_accuracy: 0.6198 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0044 - accuracy: 0.6433 - val_loss: 1.0782 - val_accuracy: 0.6210 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 18/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9987 - accuracy: 0.6465 - val_loss: 1.0770 - val_accuracy: 0.6211 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0024 - accuracy: 0.6446 - val_loss: 1.0770 - val_accuracy: 0.6206 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9962 - accuracy: 0.6463 - val_loss: 1.0767 - val_accuracy: 0.6203 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 21/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9996 - accuracy: 0.6473 - val_loss: 1.0749 - val_accuracy: 0.6207 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 22/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9964 - accuracy: 0.6449 - val_loss: 1.0747 - val_accuracy: 0.6206 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9940 - accuracy: 0.6460 - val_loss: 1.0742 - val_accuracy: 0.6207 - lr: 1.0000e-05
# SC Swish
#  val loss: 1.0742400884628296, val acc: 0.6207000017166138
#
# [<keras.callbacks.History object at 0x7f177a29ee10>, <keras.callbacks.History object at 0x7f177a2a8fd0>, <keras.callbacks.History object at 0x7f17665f6190>, <keras.callbacks.History object at 0x7f176662d510>, <keras.callbacks.History object at 0x7f1766543e50>]

# %%
result
# Out:
# [<keras.callbacks.History at 0x7f177a29ee10>,
#  <keras.callbacks.History at 0x7f177a2a8fd0>,
#  <keras.callbacks.History at 0x7f17665f6190>,
#  <keras.callbacks.History at 0x7f176662d510>,
#  <keras.callbacks.History at 0x7f1766543e50>]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
import matplotlib.pyplot as plt
new_act_arr = act_func[0:]
new_results = result[0:]

def plot_act_func_results(results, activation_functions = []):
    plt.figure(figsize=(10,10))
    plt.style.use('seaborn-poster')
    
    # Plot validation accuracy values
    for act_func in results:
        plt.plot(act_func.history['val_accuracy'])
        
    plt.title('Model accuracy')
    plt.ylabel('Test Accuracy')
    plt.xlabel('Epoch')
    plt.legend(activation_functions)
    plt.show()

    # Plot validation loss values
    plt.figure(figsize=(10,10))
    
    for act_func in results:
        plt.plot(act_func.history['val_loss'])
        
    plt.title('Model loss')
    plt.ylabel('Test Loss')
    plt.xlabel('Epoch')
    plt.legend(activation_functions)
    plt.show()

plot_act_func_results(new_results, new_act_arr)

# %%
import seaborn as sns
# sns.set_theme(style="darkgrid")
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def tanh(x):
    return (np.exp(x)-np.exp(-x)) / (np.exp(x) + np.exp(-x))

def der_hyperb(x):
    return 1 - ((np.exp(x)-np.exp(-x)) / (np.exp(x) + np.exp(-x)))**2

import numpy as np
import matplotlib.pyplot as plt

# Data which will go through activations
x = np.linspace(-10,10,200)
plt.figure(figsize=(12,6))
plt.style.use('seaborn-poster')

plt.plot(x, swish(x), label="Swish")
plt.plot(x, SoftClipping_Swish(x), label="SC Swish")
plt.plot(x, relu(x), label="ReLU")
plt.plot(x, sigmoid(x), label="Sigmoid")
plt.xlabel('x')
plt.ylabel('y = f(x)')
plt.axhline(lw=1, c='black')
plt.axvline(lw=1, c='black')
plt.grid(alpha=0.4, ls='-.')
# plt.box(on=None)
plt.title("Activation functions", fontsize = 16)
plt.legend()
plt.show()
